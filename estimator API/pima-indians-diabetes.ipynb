# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_nor = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_nor] = diabetes[cols_to_nor].apply(lambda x:(x - x.min() / (x.max() - x.min())))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0              6.0               0.743719        0.590164  0.353535  0.000000
# 1              1.0               0.427136        0.540984  0.292929  0.000000
# 2              8.0               0.919598        0.524590  0.000000  0.000000
# 3              1.0               0.447236        0.540984  0.232323  0.111111
# 4              0.0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group' , hash_bucket_size=10)

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age , boundaries=[20 , 30 , 40 ,50 , 60 , 70, 80])

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_bucket]

# %%
x_data = diabetes.drop('Class' , axis = 1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0              6.0               0.743719        0.590164  0.353535  0.000000
# 1              1.0               0.427136        0.540984  0.292929  0.000000
# 2              8.0               0.919598        0.524590  0.000000  0.000000
# 3              1.0               0.447236        0.540984  0.232323  0.111111
# 4              0.0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.3, random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn( x = X_train , y = y_train , batch_size=10 , num_epochs=1000 , shuffle= True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols , n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmp7x3v0cc9
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': 1, '_model_dir': 'C:\\Users\\PERSON~1.SHR\\AppData\\Local\\Temp\\tmp7x3v0cc9', '_session_config': None, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100}

# %%
model.train(input_fn=input_func , steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmp7x3v0cc9\model.ckpt.
# INFO:tensorflow:loss = 6.93147, step = 1
# INFO:tensorflow:global_step/sec: 208.4
# INFO:tensorflow:loss = 6.25778, step = 101 (0.486 sec)
# INFO:tensorflow:global_step/sec: 211.373
# INFO:tensorflow:loss = 8.04793, step = 201 (0.473 sec)
# INFO:tensorflow:global_step/sec: 236.794
# INFO:tensorflow:loss = 4.61087, step = 301 (0.429 sec)
# INFO:tensorflow:global_step/sec: 231.829
# INFO:tensorflow:loss = 4.19518, step = 401 (0.431 sec)
# INFO:tensorflow:global_step/sec: 218.666
# INFO:tensorflow:loss = 5.62108, step = 501 (0.454 sec)
# INFO:tensorflow:global_step/sec: 243.329
# INFO:tensorflow:loss = 4.20299, step = 601 (0.406 sec)
# INFO:tensorflow:global_step/sec: 251.159
# INFO:tensorflow:loss = 3.70708, step = 701 (0.402 sec)
# INFO:tensorflow:global_step/sec: 251.913
# INFO:tensorflow:loss = 6.28495, step = 801 (0.397 sec)
# INFO:tensorflow:global_step/sec: 264.243
# INFO:tensorflow:loss = 7.13615, step = 901 (0.374 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmp7x3v0cc9\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.2116.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn( x = X_test , y = y_test ,batch_size=10 , num_epochs=1000 , shuffle= False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-12-19-20:06:36
# INFO:tensorflow:Restoring parameters from C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmp7x3v0cc9\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-12-19-20:08:01
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.748918, accuracy_baseline = 0.649351, auc = 0.808395, auc_precision_recall = 0.655179, average_loss = 0.520802, global_step = 1000, label/mean = 0.350649, loss = 5.20802, prediction/mean = 0.373858

# %%
results
# Out:
# {'accuracy': 0.74891776,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.80839503,
#  'auc_precision_recall': 0.65517879,
#  'average_loss': 0.52080166,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.2080164,
#  'prediction/mean': 0.37385818}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn( x = X_test , batch_size=10 , num_epochs=1 , shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmp7x3v0cc9\model.ckpt-1000
# [{'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52800542], dtype=float32),
#   'logits': array([ 0.11213905], dtype=float32),
#   'probabilities': array([ 0.47199458,  0.52800542], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65850586], dtype=float32),
#   'logits': array([ 0.65664285], dtype=float32),
#   'probabilities': array([ 0.34149414,  0.65850586], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3767916], dtype=float32),
#   'logits': array([-0.50318867], dtype=float32),
#   'probabilities': array([ 0.6232084 ,  0.37679163], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34008354], dtype=float32),
#   'logits': array([-0.66292197], dtype=float32),
#   'probabilities': array([ 0.65991646,  0.34008354], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15570787], dtype=float32),
#   'logits': array([-1.69051695], dtype=float32),
#   'probabilities': array([ 0.8442921 ,  0.15570787], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69942027], dtype=float32),
#   'logits': array([ 0.84453875], dtype=float32),
#   'probabilities': array([ 0.30057973,  0.69942027], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62173176], dtype=float32),
#   'logits': array([ 0.49690515], dtype=float32),
#   'probabilities': array([ 0.37826827,  0.62173176], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30654016], dtype=float32),
#   'logits': array([-0.81634462], dtype=float32),
#   'probabilities': array([ 0.69345987,  0.30654016], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22022398], dtype=float32),
#   'logits': array([-1.26436162], dtype=float32),
#   'probabilities': array([ 0.77977598,  0.22022396], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24845959], dtype=float32),
#   'logits': array([-1.10684478], dtype=float32),
#   'probabilities': array([ 0.75154036,  0.24845958], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14771292], dtype=float32),
#   'logits': array([-1.75265288], dtype=float32),
#   'probabilities': array([ 0.85228705,  0.1477129 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17308371], dtype=float32),
#   'logits': array([-1.56392813], dtype=float32),
#   'probabilities': array([ 0.82691634,  0.17308371], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3084079], dtype=float32),
#   'logits': array([-0.80757308], dtype=float32),
#   'probabilities': array([ 0.6915921,  0.3084079], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55676919], dtype=float32),
#   'logits': array([ 0.22806007], dtype=float32),
#   'probabilities': array([ 0.44323084,  0.55676919], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20138417], dtype=float32),
#   'logits': array([-1.37766552], dtype=float32),
#   'probabilities': array([ 0.79861581,  0.20138419], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34728304], dtype=float32),
#   'logits': array([-0.63100338], dtype=float32),
#   'probabilities': array([ 0.65271688,  0.34728304], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38152525], dtype=float32),
#   'logits': array([-0.48307925], dtype=float32),
#   'probabilities': array([ 0.61847472,  0.38152528], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14857084], dtype=float32),
#   'logits': array([-1.7458545], dtype=float32),
#   'probabilities': array([ 0.85142916,  0.14857082], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37915406], dtype=float32),
#   'logits': array([-0.4931404], dtype=float32),
#   'probabilities': array([ 0.62084597,  0.37915406], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15124908], dtype=float32),
#   'logits': array([-1.72483778], dtype=float32),
#   'probabilities': array([ 0.84875095,  0.15124908], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2079951], dtype=float32),
#   'logits': array([-1.33705306], dtype=float32),
#   'probabilities': array([ 0.79200494,  0.20799512], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28160378], dtype=float32),
#   'logits': array([-0.93652022], dtype=float32),
#   'probabilities': array([ 0.71839625,  0.28160378], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61504561], dtype=float32),
#   'logits': array([ 0.46857172], dtype=float32),
#   'probabilities': array([ 0.38495436,  0.61504561], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23202521], dtype=float32),
#   'logits': array([-1.19691086], dtype=float32),
#   'probabilities': array([ 0.76797479,  0.23202522], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18559526], dtype=float32),
#   'logits': array([-1.47888923], dtype=float32),
#   'probabilities': array([ 0.81440473,  0.18559524], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78629363], dtype=float32),
#   'logits': array([ 1.30272722], dtype=float32),
#   'probabilities': array([ 0.21370639,  0.78629363], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16846666], dtype=float32),
#   'logits': array([-1.59653354], dtype=float32),
#   'probabilities': array([ 0.83153331,  0.16846666], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33630419], dtype=float32),
#   'logits': array([-0.6798079], dtype=float32),
#   'probabilities': array([ 0.66369581,  0.33630419], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11661504], dtype=float32),
#   'logits': array([-2.02488279], dtype=float32),
#   'probabilities': array([ 0.883385  ,  0.11661505], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56339645], dtype=float32),
#   'logits': array([ 0.25495785], dtype=float32),
#   'probabilities': array([ 0.43660358,  0.56339639], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.94345349], dtype=float32),
#   'logits': array([ 2.81448269], dtype=float32),
#   'probabilities': array([ 0.05654656,  0.94345349], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43013874], dtype=float32),
#   'logits': array([-0.28128511], dtype=float32),
#   'probabilities': array([ 0.56986129,  0.43013877], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3305195], dtype=float32),
#   'logits': array([-0.70583642], dtype=float32),
#   'probabilities': array([ 0.6694805,  0.3305195], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55606705], dtype=float32),
#   'logits': array([ 0.22521514], dtype=float32),
#   'probabilities': array([ 0.44393304,  0.55606705], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25278309], dtype=float32),
#   'logits': array([-1.08382368], dtype=float32),
#   'probabilities': array([ 0.74721688,  0.25278312], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38556734], dtype=float32),
#   'logits': array([-0.46598357], dtype=float32),
#   'probabilities': array([ 0.61443269,  0.38556731], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48032066], dtype=float32),
#   'logits': array([-0.078758], dtype=float32),
#   'probabilities': array([ 0.51967931,  0.48032066], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61917943], dtype=float32),
#   'logits': array([ 0.48606676], dtype=float32),
#   'probabilities': array([ 0.3808206 ,  0.61917943], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77338892], dtype=float32),
#   'logits': array([ 1.22754693], dtype=float32),
#   'probabilities': array([ 0.22661105,  0.77338892], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34321144], dtype=float32),
#   'logits': array([-0.64901549], dtype=float32),
#   'probabilities': array([ 0.65678859,  0.34321144], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17425126], dtype=float32),
#   'logits': array([-1.55579233], dtype=float32),
#   'probabilities': array([ 0.82574874,  0.17425124], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58837831], dtype=float32),
#   'logits': array([ 0.35726529], dtype=float32),
#   'probabilities': array([ 0.41162175,  0.58837831], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16524714], dtype=float32),
#   'logits': array([-1.61969352], dtype=float32),
#   'probabilities': array([ 0.8347528 ,  0.16524713], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50715661], dtype=float32),
#   'logits': array([ 0.02862847], dtype=float32),
#   'probabilities': array([ 0.49284336,  0.50715661], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14906907], dtype=float32),
#   'logits': array([-1.74192119], dtype=float32),
#   'probabilities': array([ 0.85093093,  0.14906907], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12629884], dtype=float32),
#   'logits': array([-1.93408751], dtype=float32),
#   'probabilities': array([ 0.8737011 ,  0.12629884], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61294502], dtype=float32),
#   'logits': array([ 0.45970851], dtype=float32),
#   'probabilities': array([ 0.38705498,  0.61294502], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19815479], dtype=float32),
#   'logits': array([-1.39786708], dtype=float32),
#   'probabilities': array([ 0.80184519,  0.19815479], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2038966], dtype=float32),
#   'logits': array([-1.3621161], dtype=float32),
#   'probabilities': array([ 0.79610336,  0.20389658], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14180784], dtype=float32),
#   'logits': array([-1.8003552], dtype=float32),
#   'probabilities': array([ 0.85819221,  0.14180784], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1809908], dtype=float32),
#   'logits': array([-1.50964916], dtype=float32),
#   'probabilities': array([ 0.81900918,  0.18099079], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26248884], dtype=float32),
#   'logits': array([-1.03307259], dtype=float32),
#   'probabilities': array([ 0.73751116,  0.26248884], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26496032], dtype=float32),
#   'logits': array([-1.02034438], dtype=float32),
#   'probabilities': array([ 0.73503965,  0.26496032], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35987449], dtype=float32),
#   'logits': array([-0.57590902], dtype=float32),
#   'probabilities': array([ 0.64012551,  0.35987446], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12924898], dtype=float32),
#   'logits': array([-1.90761542], dtype=float32),
#   'probabilities': array([ 0.87075102,  0.12924899], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2346511], dtype=float32),
#   'logits': array([-1.18223214], dtype=float32),
#   'probabilities': array([ 0.76534891,  0.2346511 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22421815], dtype=float32),
#   'logits': array([-1.24125195], dtype=float32),
#   'probabilities': array([ 0.77578181,  0.22421813], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20321323], dtype=float32),
#   'logits': array([-1.36633122], dtype=float32),
#   'probabilities': array([ 0.79678679,  0.20321326], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49990383], dtype=float32),
#   'logits': array([-0.00038487], dtype=float32),
#   'probabilities': array([ 0.5000962 ,  0.49990377], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1679787], dtype=float32),
#   'logits': array([-1.60002077], dtype=float32),
#   'probabilities': array([ 0.83202124,  0.16797869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22750334], dtype=float32),
#   'logits': array([-1.22246277], dtype=float32),
#   'probabilities': array([ 0.7724967 ,  0.22750336], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62897062], dtype=float32),
#   'logits': array([ 0.52780348], dtype=float32),
#   'probabilities': array([ 0.37102932,  0.62897062], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6530472], dtype=float32),
#   'logits': array([ 0.63246065], dtype=float32),
#   'probabilities': array([ 0.34695283,  0.6530472 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51087052], dtype=float32),
#   'logits': array([ 0.04348892], dtype=float32),
#   'probabilities': array([ 0.48912948,  0.51087052], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37484378], dtype=float32),
#   'logits': array([-0.51149219], dtype=float32),
#   'probabilities': array([ 0.62515622,  0.37484381], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49017334], dtype=float32),
#   'logits': array([-0.03931171], dtype=float32),
#   'probabilities': array([ 0.50982666,  0.49017334], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19546303], dtype=float32),
#   'logits': array([-1.41489565], dtype=float32),
#   'probabilities': array([ 0.804537  ,  0.19546303], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19792254], dtype=float32),
#   'logits': array([-1.39932942], dtype=float32),
#   'probabilities': array([ 0.80207747,  0.19792254], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14670576], dtype=float32),
#   'logits': array([-1.76067543], dtype=float32),
#   'probabilities': array([ 0.85329425,  0.14670578], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13708119], dtype=float32),
#   'logits': array([-1.83974719], dtype=float32),
#   'probabilities': array([ 0.86291879,  0.13708119], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64659125], dtype=float32),
#   'logits': array([ 0.60408908], dtype=float32),
#   'probabilities': array([ 0.35340872,  0.64659125], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23803364], dtype=float32),
#   'logits': array([-1.16349053], dtype=float32),
#   'probabilities': array([ 0.76196635,  0.23803359], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43771854], dtype=float32),
#   'logits': array([-0.25042641], dtype=float32),
#   'probabilities': array([ 0.56228149,  0.43771857], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59355503], dtype=float32),
#   'logits': array([ 0.37868148], dtype=float32),
#   'probabilities': array([ 0.40644494,  0.59355503], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29943106], dtype=float32),
#   'logits': array([-0.85000861], dtype=float32),
#   'probabilities': array([ 0.70056891,  0.29943106], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61763442], dtype=float32),
#   'logits': array([ 0.47951943], dtype=float32),
#   'probabilities': array([ 0.38236564,  0.61763442], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14155276], dtype=float32),
#   'logits': array([-1.80245268], dtype=float32),
#   'probabilities': array([ 0.85844719,  0.14155275], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61926764], dtype=float32),
#   'logits': array([ 0.48644084], dtype=float32),
#   'probabilities': array([ 0.38073239,  0.61926764], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13637055], dtype=float32),
#   'logits': array([-1.84576797], dtype=float32),
#   'probabilities': array([ 0.86362946,  0.13637054], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57345927], dtype=float32),
#   'logits': array([ 0.29597908], dtype=float32),
#   'probabilities': array([ 0.42654073,  0.57345927], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35504144], dtype=float32),
#   'logits': array([-0.5969516], dtype=float32),
#   'probabilities': array([ 0.64495856,  0.35504141], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16798778], dtype=float32),
#   'logits': array([-1.59995592], dtype=float32),
#   'probabilities': array([ 0.83201224,  0.16798778], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57549042], dtype=float32),
#   'logits': array([ 0.30428809], dtype=float32),
#   'probabilities': array([ 0.42450956,  0.57549042], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61149329], dtype=float32),
#   'logits': array([ 0.45359355], dtype=float32),
#   'probabilities': array([ 0.38850671,  0.61149329], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5741694], dtype=float32),
#   'logits': array([ 0.29888278], dtype=float32),
#   'probabilities': array([ 0.42583063,  0.5741694 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16387478], dtype=float32),
#   'logits': array([-1.62967587], dtype=float32),
#   'probabilities': array([ 0.83612525,  0.16387478], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39856046], dtype=float32),
#   'logits': array([-0.41146678], dtype=float32),
#   'probabilities': array([ 0.60143954,  0.39856046], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17772891], dtype=float32),
#   'logits': array([-1.53181076], dtype=float32),
#   'probabilities': array([ 0.82227105,  0.17772891], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70459872], dtype=float32),
#   'logits': array([ 0.86929387], dtype=float32),
#   'probabilities': array([ 0.29540125,  0.70459872], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.8017022], dtype=float32),
#   'logits': array([ 1.39696717], dtype=float32),
#   'probabilities': array([ 0.19829781,  0.8017022 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63444322], dtype=float32),
#   'logits': array([ 0.55132633], dtype=float32),
#   'probabilities': array([ 0.36555675,  0.63444322], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23295966], dtype=float32),
#   'logits': array([-1.19167411], dtype=float32),
#   'probabilities': array([ 0.76704037,  0.23295967], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51371527], dtype=float32),
#   'logits': array([ 0.05487478], dtype=float32),
#   'probabilities': array([ 0.48628476,  0.51371527], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39999875], dtype=float32),
#   'logits': array([-0.40547031], dtype=float32),
#   'probabilities': array([ 0.60000128,  0.39999875], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43357944], dtype=float32),
#   'logits': array([-0.2672618], dtype=float32),
#   'probabilities': array([ 0.56642056,  0.43357944], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36797509], dtype=float32),
#   'logits': array([-0.54091358], dtype=float32),
#   'probabilities': array([ 0.63202494,  0.36797509], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40753883], dtype=float32),
#   'logits': array([-0.37414914], dtype=float32),
#   'probabilities': array([ 0.59246117,  0.40753883], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16052657], dtype=float32),
#   'logits': array([-1.65431523], dtype=float32),
#   'probabilities': array([ 0.83947343,  0.16052659], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5907793], dtype=float32),
#   'logits': array([ 0.3671878], dtype=float32),
#   'probabilities': array([ 0.40922073,  0.5907793 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5880813], dtype=float32),
#   'logits': array([ 0.35603911], dtype=float32),
#   'probabilities': array([ 0.41191873,  0.5880813 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25757882], dtype=float32),
#   'logits': array([-1.05859089], dtype=float32),
#   'probabilities': array([ 0.74242115,  0.25757882], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18192773], dtype=float32),
#   'logits': array([-1.5033412], dtype=float32),
#   'probabilities': array([ 0.81807226,  0.18192773], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16830802], dtype=float32),
#   'logits': array([-1.5976665], dtype=float32),
#   'probabilities': array([ 0.83169192,  0.16830799], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28580934], dtype=float32),
#   'logits': array([-0.91582501], dtype=float32),
#   'probabilities': array([ 0.71419066,  0.28580934], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36063004], dtype=float32),
#   'logits': array([-0.57263076], dtype=float32),
#   'probabilities': array([ 0.63936996,  0.36063001], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13937892], dtype=float32),
#   'logits': array([-1.82045805], dtype=float32),
#   'probabilities': array([ 0.86062109,  0.13937892], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36214069], dtype=float32),
#   'logits': array([-0.56608498], dtype=float32),
#   'probabilities': array([ 0.63785934,  0.36214072], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25443137], dtype=float32),
#   'logits': array([-1.07511616], dtype=float32),
#   'probabilities': array([ 0.74556869,  0.25443137], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11194494], dtype=float32),
#   'logits': array([-2.07102656], dtype=float32),
#   'probabilities': array([ 0.88805503,  0.11194494], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13890778], dtype=float32),
#   'logits': array([-1.82439137], dtype=float32),
#   'probabilities': array([ 0.86109221,  0.13890778], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75819975], dtype=float32),
#   'logits': array([ 1.14283466], dtype=float32),
#   'probabilities': array([ 0.24180031,  0.75819975], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16889633], dtype=float32),
#   'logits': array([-1.59346938], dtype=float32),
#   'probabilities': array([ 0.83110368,  0.16889635], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13969728], dtype=float32),
#   'logits': array([-1.8178066], dtype=float32),
#   'probabilities': array([ 0.86030275,  0.13969727], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16442233], dtype=float32),
#   'logits': array([-1.62568498], dtype=float32),
#   'probabilities': array([ 0.83557767,  0.16442233], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51781237], dtype=float32),
#   'logits': array([ 0.0712797], dtype=float32),
#   'probabilities': array([ 0.4821876 ,  0.51781237], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46700805], dtype=float32),
#   'logits': array([-0.13215977], dtype=float32),
#   'probabilities': array([ 0.53299195,  0.46700805], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22670326], dtype=float32),
#   'logits': array([-1.22702098], dtype=float32),
#   'probabilities': array([ 0.77329677,  0.22670324], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45417163], dtype=float32),
#   'logits': array([-0.18382949], dtype=float32),
#   'probabilities': array([ 0.54582834,  0.45417157], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19127028], dtype=float32),
#   'logits': array([-1.44177723], dtype=float32),
#   'probabilities': array([ 0.80872971,  0.19127028], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24785811], dtype=float32),
#   'logits': array([-1.11006856], dtype=float32),
#   'probabilities': array([ 0.75214183,  0.24785809], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53159529], dtype=float32),
#   'logits': array([ 0.1265499], dtype=float32),
#   'probabilities': array([ 0.46840465,  0.53159529], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50117016], dtype=float32),
#   'logits': array([ 0.00468063], dtype=float32),
#   'probabilities': array([ 0.49882984,  0.50117016], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14027984], dtype=float32),
#   'logits': array([-1.81296766], dtype=float32),
#   'probabilities': array([ 0.85972017,  0.14027984], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42540672], dtype=float32),
#   'logits': array([-0.30061668], dtype=float32),
#   'probabilities': array([ 0.57459331,  0.42540675], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66254103], dtype=float32),
#   'logits': array([ 0.67463845], dtype=float32),
#   'probabilities': array([ 0.337459  ,  0.66254103], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52982348], dtype=float32),
#   'logits': array([ 0.11943573], dtype=float32),
#   'probabilities': array([ 0.47017649,  0.52982348], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38877404], dtype=float32),
#   'logits': array([-0.45246837], dtype=float32),
#   'probabilities': array([ 0.61122596,  0.38877407], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60322398], dtype=float32),
#   'logits': array([ 0.41891652], dtype=float32),
#   'probabilities': array([ 0.39677605,  0.60322398], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24132223], dtype=float32),
#   'logits': array([-1.14544404], dtype=float32),
#   'probabilities': array([ 0.75867784,  0.24132225], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19575089], dtype=float32),
#   'logits': array([-1.41306615], dtype=float32),
#   'probabilities': array([ 0.80424911,  0.19575089], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13751787], dtype=float32),
#   'logits': array([-1.83606052], dtype=float32),
#   'probabilities': array([ 0.86248213,  0.13751787], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29746452], dtype=float32),
#   'logits': array([-0.85940087], dtype=float32),
#   'probabilities': array([ 0.70253545,  0.29746452], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52247477], dtype=float32),
#   'logits': array([ 0.08995956], dtype=float32),
#   'probabilities': array([ 0.47752529,  0.52247477], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65968096], dtype=float32),
#   'logits': array([ 0.6618728], dtype=float32),
#   'probabilities': array([ 0.34031904,  0.65968096], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24365726], dtype=float32),
#   'logits': array([-1.13273203], dtype=float32),
#   'probabilities': array([ 0.75634277,  0.24365728], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18168573], dtype=float32),
#   'logits': array([-1.50496805], dtype=float32),
#   'probabilities': array([ 0.81831425,  0.18168572], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4386481], dtype=float32),
#   'logits': array([-0.24665052], dtype=float32),
#   'probabilities': array([ 0.5613519 ,  0.43864807], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21963818], dtype=float32),
#   'logits': array([-1.26777601], dtype=float32),
#   'probabilities': array([ 0.78036177,  0.2196382 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13814913], dtype=float32),
#   'logits': array([-1.83074856], dtype=float32),
#   'probabilities': array([ 0.86185086,  0.13814913], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19514552], dtype=float32),
#   'logits': array([-1.41691601], dtype=float32),
#   'probabilities': array([ 0.80485451,  0.19514552], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13928568], dtype=float32),
#   'logits': array([-1.82123554], dtype=float32),
#   'probabilities': array([ 0.86071432,  0.13928568], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42425224], dtype=float32),
#   'logits': array([-0.30534142], dtype=float32),
#   'probabilities': array([ 0.57574779,  0.42425227], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77897602], dtype=float32),
#   'logits': array([ 1.25970888], dtype=float32),
#   'probabilities': array([ 0.22102402,  0.77897602], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77848363], dtype=float32),
#   'logits': array([ 1.25685167], dtype=float32),
#   'probabilities': array([ 0.22151633,  0.77848363], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50919747], dtype=float32),
#   'logits': array([ 0.03679395], dtype=float32),
#   'probabilities': array([ 0.49080256,  0.50919747], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53221959], dtype=float32),
#   'logits': array([ 0.12905711], dtype=float32),
#   'probabilities': array([ 0.46778044,  0.53221959], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61047411], dtype=float32),
#   'logits': array([ 0.44930571], dtype=float32),
#   'probabilities': array([ 0.38952583,  0.61047411], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10790259], dtype=float32),
#   'logits': array([-2.11234641], dtype=float32),
#   'probabilities': array([ 0.89209741,  0.10790259], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54076463], dtype=float32),
#   'logits': array([ 0.16342121], dtype=float32),
#   'probabilities': array([ 0.45923537,  0.54076463], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76699561], dtype=float32),
#   'logits': array([ 1.19142365], dtype=float32),
#   'probabilities': array([ 0.23300444,  0.76699561], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44504836], dtype=float32),
#   'logits': array([-0.22069794], dtype=float32),
#   'probabilities': array([ 0.55495161,  0.44504839], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28486943], dtype=float32),
#   'logits': array([-0.92043412], dtype=float32),
#   'probabilities': array([ 0.71513057,  0.28486946], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34877732], dtype=float32),
#   'logits': array([-0.62441796], dtype=float32),
#   'probabilities': array([ 0.65122271,  0.34877735], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61277348], dtype=float32),
#   'logits': array([ 0.45898563], dtype=float32),
#   'probabilities': array([ 0.38722646,  0.61277348], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22461109], dtype=float32),
#   'logits': array([-1.23899436], dtype=float32),
#   'probabilities': array([ 0.77538896,  0.22461109], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63300645], dtype=float32),
#   'logits': array([ 0.54513651], dtype=float32),
#   'probabilities': array([ 0.36699349,  0.63300645], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44024113], dtype=float32),
#   'logits': array([-0.24018347], dtype=float32),
#   'probabilities': array([ 0.55975884,  0.4402411 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45571563], dtype=float32),
#   'logits': array([-0.17760289], dtype=float32),
#   'probabilities': array([ 0.5442844 ,  0.45571566], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15151061], dtype=float32),
#   'logits': array([-1.72280192], dtype=float32),
#   'probabilities': array([ 0.84848934,  0.1515106 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19246072], dtype=float32),
#   'logits': array([-1.43409967], dtype=float32),
#   'probabilities': array([ 0.80753928,  0.19246072], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21002282], dtype=float32),
#   'logits': array([-1.32478786], dtype=float32),
#   'probabilities': array([ 0.78997719,  0.21002284], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41465634], dtype=float32),
#   'logits': array([-0.34474909], dtype=float32),
#   'probabilities': array([ 0.58534366,  0.41465634], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14051373], dtype=float32),
#   'logits': array([-1.81102967], dtype=float32),
#   'probabilities': array([ 0.85948622,  0.14051372], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73696816], dtype=float32),
#   'logits': array([ 1.03026962], dtype=float32),
#   'probabilities': array([ 0.26303184,  0.73696816], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19137129], dtype=float32),
#   'logits': array([-1.44112444], dtype=float32),
#   'probabilities': array([ 0.80862874,  0.19137129], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51941276], dtype=float32),
#   'logits': array([ 0.07769006], dtype=float32),
#   'probabilities': array([ 0.48058724,  0.51941276], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14699267], dtype=float32),
#   'logits': array([-1.75838542], dtype=float32),
#   'probabilities': array([ 0.85300732,  0.14699267], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69703889], dtype=float32),
#   'logits': array([ 0.83323687], dtype=float32),
#   'probabilities': array([ 0.30296108,  0.69703889], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31043136], dtype=float32),
#   'logits': array([-0.79810339], dtype=float32),
#   'probabilities': array([ 0.68956864,  0.31043136], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20526031], dtype=float32),
#   'logits': array([-1.35373569], dtype=float32),
#   'probabilities': array([ 0.79473972,  0.20526032], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35060778], dtype=float32),
#   'logits': array([-0.61636865], dtype=float32),
#   'probabilities': array([ 0.64939219,  0.35060778], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3504138], dtype=float32),
#   'logits': array([-0.61722076], dtype=float32),
#   'probabilities': array([ 0.6495862,  0.3504138], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18158637], dtype=float32),
#   'logits': array([-1.50563645], dtype=float32),
#   'probabilities': array([ 0.81841362,  0.18158637], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71380222], dtype=float32),
#   'logits': array([ 0.91392285], dtype=float32),
#   'probabilities': array([ 0.28619778,  0.71380222], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21719302], dtype=float32),
#   'logits': array([-1.28209972], dtype=float32),
#   'probabilities': array([ 0.78280699,  0.21719302], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18539561], dtype=float32),
#   'logits': array([-1.48021054], dtype=float32),
#   'probabilities': array([ 0.8146044 ,  0.18539563], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2877517], dtype=float32),
#   'logits': array([-0.90632856], dtype=float32),
#   'probabilities': array([ 0.71224827,  0.2877517 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44940779], dtype=float32),
#   'logits': array([-0.20306379], dtype=float32),
#   'probabilities': array([ 0.55059218,  0.44940776], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26556173], dtype=float32),
#   'logits': array([-1.01725864], dtype=float32),
#   'probabilities': array([ 0.7344383 ,  0.26556173], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13091823], dtype=float32),
#   'logits': array([-1.89286423], dtype=float32),
#   'probabilities': array([ 0.86908174,  0.13091823], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.83615452], dtype=float32),
#   'logits': array([ 1.62988949], dtype=float32),
#   'probabilities': array([ 0.16384549,  0.83615452], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64691526], dtype=float32),
#   'logits': array([ 0.60550708], dtype=float32),
#   'probabilities': array([ 0.35308477,  0.64691526], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52350789], dtype=float32),
#   'logits': array([ 0.09410101], dtype=float32),
#   'probabilities': array([ 0.47649208,  0.52350789], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73957527], dtype=float32),
#   'logits': array([ 1.04376221], dtype=float32),
#   'probabilities': array([ 0.2604247 ,  0.73957527], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13898966], dtype=float32),
#   'logits': array([-1.82370698], dtype=float32),
#   'probabilities': array([ 0.86101031,  0.13898966], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13828862], dtype=float32),
#   'logits': array([-1.82957745], dtype=float32),
#   'probabilities': array([ 0.86171138,  0.13828862], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23422958], dtype=float32),
#   'logits': array([-1.1845808], dtype=float32),
#   'probabilities': array([ 0.76577044,  0.23422955], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34588423], dtype=float32),
#   'logits': array([-0.63718021], dtype=float32),
#   'probabilities': array([ 0.65411574,  0.3458842 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35234722], dtype=float32),
#   'logits': array([-0.60873753], dtype=float32),
#   'probabilities': array([ 0.64765275,  0.35234722], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53920603], dtype=float32),
#   'logits': array([ 0.15714663], dtype=float32),
#   'probabilities': array([ 0.460794  ,  0.53920603], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58830374], dtype=float32),
#   'logits': array([ 0.35695761], dtype=float32),
#   'probabilities': array([ 0.41169623,  0.58830374], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42333448], dtype=float32),
#   'logits': array([-0.30909985], dtype=float32),
#   'probabilities': array([ 0.57666552,  0.42333448], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35724196], dtype=float32),
#   'logits': array([-0.58735502], dtype=float32),
#   'probabilities': array([ 0.64275801,  0.35724196], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3601613], dtype=float32),
#   'logits': array([-0.57466406], dtype=float32),
#   'probabilities': array([ 0.6398387,  0.3601613], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19578716], dtype=float32),
#   'logits': array([-1.41283584], dtype=float32),
#   'probabilities': array([ 0.80421281,  0.19578715], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6024124], dtype=float32),
#   'logits': array([ 0.41552681], dtype=float32),
#   'probabilities': array([ 0.39758769,  0.6024124 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14278924], dtype=float32),
#   'logits': array([-1.79231405], dtype=float32),
#   'probabilities': array([ 0.85721076,  0.14278926], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24113633], dtype=float32),
#   'logits': array([-1.1464597], dtype=float32),
#   'probabilities': array([ 0.75886369,  0.24113634], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54269063], dtype=float32),
#   'logits': array([ 0.17117935], dtype=float32),
#   'probabilities': array([ 0.45730937,  0.54269063], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35266945], dtype=float32),
#   'logits': array([-0.60732597], dtype=float32),
#   'probabilities': array([ 0.64733058,  0.35266945], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21193379], dtype=float32),
#   'logits': array([-1.31330824], dtype=float32),
#   'probabilities': array([ 0.78806621,  0.21193376], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28479233], dtype=float32),
#   'logits': array([-0.92081267], dtype=float32),
#   'probabilities': array([ 0.7152077 ,  0.28479236], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24111816], dtype=float32),
#   'logits': array([-1.146559], dtype=float32),
#   'probabilities': array([ 0.75888187,  0.24111816], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14752391], dtype=float32),
#   'logits': array([-1.75415492], dtype=float32),
#   'probabilities': array([ 0.85247612,  0.14752391], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22982951], dtype=float32),
#   'logits': array([-1.20927405], dtype=float32),
#   'probabilities': array([ 0.77017045,  0.22982952], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60212022], dtype=float32),
#   'logits': array([ 0.41430718], dtype=float32),
#   'probabilities': array([ 0.39787981,  0.60212022], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69507313], dtype=float32),
#   'logits': array([ 0.82394511], dtype=float32),
#   'probabilities': array([ 0.30492684,  0.69507313], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66113162], dtype=float32),
#   'logits': array([ 0.66834122], dtype=float32),
#   'probabilities': array([ 0.33886838,  0.66113162], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65556103], dtype=float32),
#   'logits': array([ 0.64357442], dtype=float32),
#   'probabilities': array([ 0.34443897,  0.65556103], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.477799], dtype=float32),
#   'logits': array([-0.08886248], dtype=float32),
#   'probabilities': array([ 0.522201,  0.477799], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32620263], dtype=float32),
#   'logits': array([-0.72541064], dtype=float32),
#   'probabilities': array([ 0.67379737,  0.32620263], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52461898], dtype=float32),
#   'logits': array([ 0.09855562], dtype=float32),
#   'probabilities': array([ 0.47538102,  0.52461898], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19187979], dtype=float32),
#   'logits': array([-1.43784165], dtype=float32),
#   'probabilities': array([ 0.80812025,  0.19187981], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17292212], dtype=float32),
#   'logits': array([-1.56505752], dtype=float32),
#   'probabilities': array([ 0.82707793,  0.17292213], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18225586], dtype=float32),
#   'logits': array([-1.50113797], dtype=float32),
#   'probabilities': array([ 0.81774414,  0.18225586], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48163411], dtype=float32),
#   'logits': array([-0.0734967], dtype=float32),
#   'probabilities': array([ 0.51836592,  0.48163408], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.05454278], dtype=float32),
#   'logits': array([-2.85268331], dtype=float32),
#   'probabilities': array([ 0.94545722,  0.05454278], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26520121], dtype=float32),
#   'logits': array([-1.01910782], dtype=float32),
#   'probabilities': array([ 0.73479873,  0.26520121], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18201745], dtype=float32),
#   'logits': array([-1.50273848], dtype=float32),
#   'probabilities': array([ 0.81798255,  0.18201745], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28304121], dtype=float32),
#   'logits': array([-0.92942584], dtype=float32),
#   'probabilities': array([ 0.71695882,  0.28304124], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24049586], dtype=float32),
#   'logits': array([-1.1499629], dtype=float32),
#   'probabilities': array([ 0.75950414,  0.24049586], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29979801], dtype=float32),
#   'logits': array([-0.84825993], dtype=float32),
#   'probabilities': array([ 0.70020205,  0.29979801], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78849262], dtype=float32),
#   'logits': array([ 1.31586313], dtype=float32),
#   'probabilities': array([ 0.21150738,  0.78849262], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18056287], dtype=float32),
#   'logits': array([-1.51253867], dtype=float32),
#   'probabilities': array([ 0.81943709,  0.18056287], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12898223], dtype=float32),
#   'logits': array([-1.90998769], dtype=float32),
#   'probabilities': array([ 0.87101775,  0.12898223], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59232962], dtype=float32),
#   'logits': array([ 0.37360436], dtype=float32),
#   'probabilities': array([ 0.40767038,  0.59232962], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50054002], dtype=float32),
#   'logits': array([ 0.00216007], dtype=float32),
#   'probabilities': array([ 0.49945998,  0.50054002], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.82675558], dtype=float32),
#   'logits': array([ 1.56280589], dtype=float32),
#   'probabilities': array([ 0.17324439,  0.82675558], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65207225], dtype=float32),
#   'logits': array([ 0.62816054], dtype=float32),
#   'probabilities': array([ 0.34792775,  0.65207225], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12733294], dtype=float32),
#   'logits': array([-1.9247489], dtype=float32),
#   'probabilities': array([ 0.87266707,  0.12733294], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63779938], dtype=float32),
#   'logits': array([ 0.56582552], dtype=float32),
#   'probabilities': array([ 0.36220062,  0.63779938], dtype=float32)}]

# %% [markdown]
# # DNN CLASSIFIER

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmprdnh0j3n
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': 1, '_model_dir': 'C:\\Users\\PERSON~1.SHR\\AppData\\Local\\Temp\\tmprdnh0j3n', '_session_config': None, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-14d882be69ef> in <module>()
# ----> 1 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model(self, input_fn, hooks)
#     628           input_fn, model_fn_lib.ModeKeys.TRAIN)
#     629       estimator_spec = self._call_model_fn(features, labels,
# --> 630                                            model_fn_lib.ModeKeys.TRAIN)
#     631       ops.add_to_collection(ops.GraphKeys.LOSSES, estimator_spec.loss)
#     632       all_hooks.extend(hooks)
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode)
#     613     if 'config' in model_fn_args:
#     614       kwargs['config'] = self.config
# --> 615     model_fn_results = self._model_fn(features=features, **kwargs)
#     616
#     617     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     269           dropout=dropout,
#     270           input_layer_partitioner=input_layer_partitioner,
# --> 271           config=config)
#     272     super(DNNClassifier, self).__init__(
#     273         model_fn=_model_fn, model_dir=model_dir, config=config)
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     100       net = feature_column_lib.input_layer(
#     101           features=features,
# --> 102           feature_columns=feature_columns)
#     103
#     104     for layer_id, num_hidden_units in enumerate(hidden_units):
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\feature_column\feature_column.py in input_layer(features, feature_columns, weight_collections, trainable)
#     211           'Items of feature_columns must be a _DenseColumn. '
#     212           'You can wrap a categorical column with an '
# --> 213           'embedding_column or indicator_column. Given: {}'.format(column))
#     214   weight_collections = list(weight_collections or [])
#     215   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _HashedCategoricalColumn(key='Group', hash_bucket_size=10, dtype=tf.string)

# %% [markdown]
# # Description

# %% [markdown]
# Deep neural network models (`DNNClassifier`, `DNNRegressor`).
#     Continuous features can be directly fed into deep neural network models.
#
#     To feed sparse features into DNN models, wrap the column with
#     `embedding_column` or `indicator_column`. `indicator_column` is recommended
#     for features with only a few possible values. For features with many
#     possible values, to reduce the size of your model, `embedding_column` is
#     recommended.
#     Wide (aka linear) models (`LinearClassifier`, `LinearRegressor`).
#     Sparse features can be fed directly into linear models. They behave like an
#     indicator column but with an efficient implementation.
#
#     It is recommended that continuous features be bucketized before being
#     fed into linear models.
#
#     Sparse features can be crossed (also known as conjuncted or combined) in
#     order to form non-linearities, and then fed into linear models.

# %%
embeded_group_col = tf.feature_column.embedding_column(assigned_group  , dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embeded_group_col, age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmpo7hgt56r
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': 1, '_model_dir': 'C:\\Users\\PERSON~1.SHR\\AppData\\Local\\Temp\\tmpo7hgt56r', '_session_config': None, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmpo7hgt56r\model.ckpt.
# INFO:tensorflow:loss = 7.22547, step = 1
# INFO:tensorflow:global_step/sec: 212.796
# INFO:tensorflow:loss = 5.35809, step = 101 (0.470 sec)
# INFO:tensorflow:global_step/sec: 272.501
# INFO:tensorflow:loss = 5.91248, step = 201 (0.373 sec)
# INFO:tensorflow:global_step/sec: 243.586
# INFO:tensorflow:loss = 4.5621, step = 301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 238.504
# INFO:tensorflow:loss = 5.75097, step = 401 (0.418 sec)
# INFO:tensorflow:global_step/sec: 191.707
# INFO:tensorflow:loss = 5.38111, step = 501 (0.524 sec)
# INFO:tensorflow:global_step/sec: 159.659
# INFO:tensorflow:loss = 4.65111, step = 601 (0.637 sec)
# INFO:tensorflow:global_step/sec: 142.975
# INFO:tensorflow:loss = 10.3796, step = 701 (0.688 sec)
# INFO:tensorflow:global_step/sec: 146.865
# INFO:tensorflow:loss = 4.94492, step = 801 (0.690 sec)
# INFO:tensorflow:global_step/sec: 170.249
# INFO:tensorflow:loss = 4.00088, step = 901 (0.582 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmpo7hgt56r\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.34776.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-12-19-20:30:16
# INFO:tensorflow:Restoring parameters from C:\Users\PERSON~1.SHR\AppData\Local\Temp\tmpo7hgt56r\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-12-19-20:30:18
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.753247, accuracy_baseline = 0.649351, auc = 0.827819, auc_precision_recall = 0.687351, average_loss = 0.498114, global_step = 1000, label/mean = 0.350649, loss = 4.79435, prediction/mean = 0.413337
# {'accuracy': 0.75324672,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.82781893,
#  'auc_precision_recall': 0.68735075,
#  'average_loss': 0.49811423,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.7943492,
#  'prediction/mean': 0.41333652}
